# %% [markdown]
# # 【Q3】Which geographical region are you currently working or attending school/university in ?
#
# - 【Q3】Which geographical region are you currently working or attending school/university in ?
# - 【Q4】Which geographical region do you most strongly associate with ?

# %%
import altair as alt
import pandas as pd
import scipy as sp
import titanite as ti

print(f"Altair {alt.__version__}")
print(f"Pandas {pd.__version__}")
print(f"SciPy {sp.__version__}")
print(f"Titanite {ti.__version__}")
# Out:
# Altair 5.0.1
# Pandas 2.0.3
# SciPy 1.11.1
# Titanite 0.4.0

# %% [markdown]
# データを読み込む

# %%
f_cfg = "../sandbox/config.toml"
f_csv = "../data/test_data/prepared_data.csv"
d = ti.Data(read_from=f_csv, load_from=f_cfg)
data = d.read()
# data.info()
# Out:
# 2023-07-23 14:26:44.118 | INFO     | titanite.preprocess:categorical_data:123 - Categorize
# 2023-07-23 14:26:44.126 | INFO     | titanite.preprocess:binned_data:229 - Binned

# %%
x = ["q03", "q04"]
headers = d.crosstab_headers(x, list(data.columns))

# %%
cross_tabs, heatmaps, chi2_data = ti.core.crosstab_loop(data, headers)
chi2_data
# Out:
#                 questions        p_value    statistic  dof
# 0                 q03-q01   4.781194e-08   232.366478  128
# 1                 q03-q02   2.431779e-01    71.488371   64
# 2                 q03-q05   3.066386e-07   181.634887   96
# 3                 q03-q06   3.268787e-14   286.965947  128
# 4                 q03-q07   8.755710e-02    61.764583   48
# 5                 q03-q08   6.391316e-04   127.063540   80
# 6                 q03-q09   4.111224e-01    33.144960   32
# 7                 q03-q11   9.114942e-02    43.091270   32
# 8   q03-q12_genderbalance   2.153759e-01    89.669966   80
# 9       q03-q12_diversity   3.943840e-02   103.557103   80
# 10         q03-q12_equity   6.468460e-02    99.986727   80
# 11      q03-q12_inclusion   2.342512e-05   142.163316   80
# 12                q03-q14   1.946006e-03   121.423876   80
# 13  q03-q17_genderbalance   1.172087e-01    59.850888   48
# 14      q03-q17_diversity   6.640423e-01    43.337633   48
# 15         q03-q17_equity   2.062843e-01    55.751333   48
# 16      q03-q17_inclusion   3.067456e-01    52.415076   48
# 17                q03-q19   7.629276e-05   136.997898   80
# 18       q03-q03_regional  3.057834e-247  1435.000000   80
# 19    q03-q03_subregional   0.000000e+00  4592.000000  256
# 20       q03-q04_regional  4.260960e-127   840.031241   80
# 21    q03-q04_subregional   0.000000e+00  2307.315589  272
# 22         q03-q10_binned   8.095560e-03   224.281239  176
# 23         q03-q13_binned   1.606049e-01   295.097649  272
# 24                q04-q01   2.089338e-11   274.586635  136
# 25                q04-q02   1.929578e-01    77.894940   68
# 26                q04-q05   2.850849e-05   169.867399  102
# 27                q04-q06   4.029291e-06   222.576102  136
# 28                q04-q07   1.609818e-01    60.925119   51
# 29                q04-q08   1.785787e-02   114.606054   85
# 30                q04-q09   5.651436e-01    32.016505   34
# 31                q04-q11   7.710115e-01    27.646675   34
# 32  q04-q12_genderbalance   1.364453e-01    99.376465   85
# 33      q04-q12_diversity   4.550747e-01    85.807414   85
# 34         q04-q12_equity   5.546859e-01    82.562159   85
# 35      q04-q12_inclusion   2.127913e-01    95.102567   85
# 36                q04-q14   1.948905e-01    95.994252   85
# 37  q04-q17_genderbalance   7.941132e-01    42.551192   51
# 38      q04-q17_diversity   7.987649e-01    42.404182   51
# 39         q04-q17_equity   9.054329e-01    38.296486   51
# 40      q04-q17_inclusion   6.852539e-01    45.653463   51
# 41                q04-q19   4.072880e-02   109.013091   85
# 42       q04-q03_regional  7.165669e-144   938.099414   85
# 43    q04-q03_subregional   0.000000e+00  2307.315589  272
# 44       q04-q04_regional  3.993863e-244  1435.000000   85
# 45    q04-q04_subregional   0.000000e+00  4879.000000  289
# 46         q04-q10_binned   3.309507e-05   274.282434  187
# 47         q04-q13_binned   3.807463e-05   394.026067  289

# %%
mark = alt.Chart(chi2_data).mark_point().encode(
    alt.X("p_value"),
    alt.Y("questions"),
    tooltip=["questions", "p_value", "dof", "statistic"]
)

rule = (
    alt.Chart()
    .mark_rule(color="orange")
    .encode(x=alt.datum(0.05))
)

(mark + rule).properties(
    width=500,
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ``p < 0.05``の項目を調べる

# %%
p005 = chi2_data.query("p_value < 0.05")
p005
# Out:
#               questions        p_value    statistic  dof
# 0               q03-q01   4.781194e-08   232.366478  128
# 2               q03-q05   3.066386e-07   181.634887   96
# 3               q03-q06   3.268787e-14   286.965947  128
# 5               q03-q08   6.391316e-04   127.063540   80
# 9     q03-q12_diversity   3.943840e-02   103.557103   80
# 11    q03-q12_inclusion   2.342512e-05   142.163316   80
# 12              q03-q14   1.946006e-03   121.423876   80
# 17              q03-q19   7.629276e-05   136.997898   80
# 18     q03-q03_regional  3.057834e-247  1435.000000   80
# 19  q03-q03_subregional   0.000000e+00  4592.000000  256
# 20     q03-q04_regional  4.260960e-127   840.031241   80
# 21  q03-q04_subregional   0.000000e+00  2307.315589  272
# 22       q03-q10_binned   8.095560e-03   224.281239  176
# 24              q04-q01   2.089338e-11   274.586635  136
# 26              q04-q05   2.850849e-05   169.867399  102
# 27              q04-q06   4.029291e-06   222.576102  136
# 29              q04-q08   1.785787e-02   114.606054   85
# 41              q04-q19   4.072880e-02   109.013091   85
# 42     q04-q03_regional  7.165669e-144   938.099414   85
# 43  q04-q03_subregional   0.000000e+00  2307.315589  272
# 44     q04-q04_regional  3.993863e-244  1435.000000   85
# 45  q04-q04_subregional   0.000000e+00  4879.000000  289
# 46       q04-q10_binned   3.309507e-05   274.282434  187
# 47       q04-q13_binned   3.807463e-05   394.026067  289

# %%
for name, hm in heatmaps.items():
    if name in list(p005.questions):
        hm.properties(
            title=name,
            width=400,
            height=400,
        ).display()
# Out:
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
