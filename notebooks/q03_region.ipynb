# %% [markdown]
# # 【Q3】Which geographical region are you currently working or attending school/university in ?
#
# - 【Q3】Which geographical region are you currently working or attending school/university in ?
# - 【Q4】Which geographical region do you most strongly associate with ?

# %%
import altair as alt
import pandas as pd
import scipy as sp
import titanite as ti

print(f"Altair {alt.__version__}")
print(f"Pandas {pd.__version__}")
print(f"SciPy {sp.__version__}")
print(f"Titanite {ti.__version__}")
# Out:
# Altair 5.0.1
# Pandas 2.0.3
# SciPy 1.11.1
# Titanite 0.4.1

# %% [markdown]
# データを読み込む

# %%
f_cfg = "../sandbox/config.toml"
f_csv = "../data/test_data/prepared_data.csv"
d = ti.Data(read_from=f_csv, load_from=f_cfg)
data = d.read()
# data.info()
# Out:
# 2023-07-23 22:50:13.231 | INFO     | titanite.preprocess:categorical_data:123 - Categorize
# 2023-07-23 22:50:13.239 | INFO     | titanite.preprocess:binned_data:229 - Binned

# %%
x = ["q03_subregional"]
headers = d.crosstab_headers(x, list(data.columns))

# %%
cross_tabs, heatmaps, chi2_data = ti.core.crosstab_loop(data, headers)
chi2_data
# Out:
#                             questions        p_value    statistic  dof
# 0                 q03_subregional-q01   4.781194e-08   232.366478  128
# 1                 q03_subregional-q02   2.431779e-01    71.488371   64
# 2                 q03_subregional-q05   3.066386e-07   181.634887   96
# 3                 q03_subregional-q06   3.268787e-14   286.965947  128
# 4                 q03_subregional-q07   8.755710e-02    61.764583   48
# 5                 q03_subregional-q08   6.391316e-04   127.063540   80
# 6                 q03_subregional-q09   4.111224e-01    33.144960   32
# 7                 q03_subregional-q11   9.114942e-02    43.091270   32
# 8   q03_subregional-q12_genderbalance   2.153759e-01    89.669966   80
# 9       q03_subregional-q12_diversity   3.943840e-02   103.557103   80
# 10         q03_subregional-q12_equity   6.468460e-02    99.986727   80
# 11      q03_subregional-q12_inclusion   2.342512e-05   142.163316   80
# 12                q03_subregional-q14   1.946006e-03   121.423876   80
# 13  q03_subregional-q17_genderbalance   1.172087e-01    59.850888   48
# 14      q03_subregional-q17_diversity   6.640423e-01    43.337633   48
# 15         q03_subregional-q17_equity   2.062843e-01    55.751333   48
# 16      q03_subregional-q17_inclusion   3.067456e-01    52.415076   48
# 17                q03_subregional-q19   7.629276e-05   136.997898   80
# 18       q03_subregional-q03_regional  3.057834e-247  1435.000000   80
# 19       q03_subregional-q04_regional  4.260960e-127   840.031241   80
# 20    q03_subregional-q04_subregional   0.000000e+00  2307.315589  272
# 21         q03_subregional-q10_binned   8.095560e-03   224.281239  176
# 22         q03_subregional-q13_binned   1.606049e-01   295.097649  272

# %%
mark = alt.Chart(chi2_data).mark_point().encode(
    alt.X("p_value"),
    alt.Y("questions"),
    tooltip=["questions", "p_value", "dof", "statistic"]
)

rule = (
    alt.Chart()
    .mark_rule(color="orange")
    .encode(x=alt.datum(0.05))
)

(mark + rule).properties(
    width=500,
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ``p < 0.05``の項目を調べる

# %%
p005 = chi2_data.query("p_value < 0.05")
p005
# Out:
#                           questions        p_value    statistic  dof
# 0               q03_subregional-q01   4.781194e-08   232.366478  128
# 2               q03_subregional-q05   3.066386e-07   181.634887   96
# 3               q03_subregional-q06   3.268787e-14   286.965947  128
# 5               q03_subregional-q08   6.391316e-04   127.063540   80
# 9     q03_subregional-q12_diversity   3.943840e-02   103.557103   80
# 11    q03_subregional-q12_inclusion   2.342512e-05   142.163316   80
# 12              q03_subregional-q14   1.946006e-03   121.423876   80
# 17              q03_subregional-q19   7.629276e-05   136.997898   80
# 18     q03_subregional-q03_regional  3.057834e-247  1435.000000   80
# 19     q03_subregional-q04_regional  4.260960e-127   840.031241   80
# 20  q03_subregional-q04_subregional   0.000000e+00  2307.315589  272
# 21       q03_subregional-q10_binned   8.095560e-03   224.281239  176

# %%
for name, hm in heatmaps.items():
    if name in list(p005.questions):
        hm.properties(
            title=name,
            width=600,
            height=400,
        ).display()
# Out:
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
