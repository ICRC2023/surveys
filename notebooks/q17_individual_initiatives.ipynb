# %% [markdown]
# # 【Q17】What are your thoughts on diversity, equity & inclusion initiatives ?
#
# 以下のポイントについて、個人の意識回答してもらった。
#
# - Gender balance
# - Diversity
# - Equity
# - Inclusion
#
# ---
#
# - グループの取り組みと個人の意識は相関があるのか？
# - グループで取り組んでいる場合、個人の意識も高まる？

# %%
import altair as alt
import pandas as pd
import scipy as sp
import titanite as ti

print(f"Altair {alt.__version__}")
print(f"Pandas {pd.__version__}")
print(f"SciPy {sp.__version__}")
print(f"Titanite {ti.__version__}")
# Out:
# Altair 5.0.1
# Pandas 2.0.3
# SciPy 1.11.1
# Titanite 0.4.0

# %% [markdown]
# データを読み込む

# %%
f_cfg = "../sandbox/config.toml"
f_csv = "../data/test_data/prepared_data.csv"
d = ti.Data(read_from=f_csv, load_from=f_cfg)
data = d.read()
# data.info()
# Out:
# 2023-07-23 13:44:02.440 | INFO     | titanite.preprocess:categorical_data:123 - Categorize
# 2023-07-23 13:44:02.448 | INFO     | titanite.preprocess:binned_data:229 - Binned

# %% [markdown]
# カイ二乗検定する

# %%
x = [
    "q12_genderbalance",
    "q12_diversity",
    "q12_equity",
    "q12_inclusion",
]
headers = d.crosstab_headers(x, list(data.columns))
# headers

# %%
cross_tabs, heatmaps, chi2_data = ti.core.crosstab_loop(data, headers)
chi2_data
# Out:
#                         questions   p_value   statistic  dof
# 0           q12_genderbalance-q01  0.021924   59.988614   40
# 1           q12_genderbalance-q02  0.683582   16.524754   20
# 2           q12_genderbalance-q03  0.215376   89.669966   80
# 3           q12_genderbalance-q04  0.136445   99.376465   85
# 4           q12_genderbalance-q05  0.630997   26.852654   30
# ..                            ...       ...         ...  ...
# 95  q12_inclusion-q03_subregional  0.000023  142.163316   80
# 96     q12_inclusion-q04_regional  0.248752   29.369852   25
# 97  q12_inclusion-q04_subregional  0.212791   95.102567   85
# 98       q12_inclusion-q10_binned  0.576646   52.346418   55
# 99       q12_inclusion-q13_binned  0.648222   79.491553   85
#
# [100 rows x 4 columns]

# %%
mark = (
    alt.Chart(chi2_data)
    .mark_point()
    .encode(
        alt.X("p_value"),
        alt.Y("questions"),
        tooltip=["questions", "p_value", "dof", "statistic"],
    )
)

rule = alt.Chart().mark_rule(color="orange").encode(x=alt.datum(0.05))

(mark + rule).properties(
    width=500,
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ``p < 0.05``の項目を確認する

# %%
p005 = chi2_data.query("p_value < 0.05")
p005
# Out:
#                               questions        p_value   statistic  dof
# 0                 q12_genderbalance-q01   2.192442e-02   59.988614   40
# 10      q12_genderbalance-q12_diversity  8.192478e-143  753.347785   25
# 11         q12_genderbalance-q12_equity  1.661531e-111  604.111131   25
# 12      q12_genderbalance-q12_inclusion   1.887248e-99  546.288615   25
# 13                q12_genderbalance-q14   1.667273e-40  257.645141   25
# 14  q12_genderbalance-q17_genderbalance   1.854209e-13   93.890945   15
# 15      q12_genderbalance-q17_diversity   4.162421e-14   97.336612   15
# 16         q12_genderbalance-q17_equity   1.814370e-13   93.941174   15
# 17      q12_genderbalance-q17_inclusion   2.456154e-13   93.240407   15
# 24         q12_genderbalance-q13_binned   6.052050e-04  133.589154   85
# 26                    q12_diversity-q02   7.419485e-03   38.625475   20
# 27                    q12_diversity-q03   3.943840e-02  103.557103   80
# 35      q12_diversity-q12_genderbalance  8.192478e-143  753.347785   25
# 36             q12_diversity-q12_equity  2.964183e-119  641.159182   25
# 37          q12_diversity-q12_inclusion  4.416252e-108  587.709633   25
# 38                    q12_diversity-q14   3.148340e-16  130.378606   25
# 39      q12_diversity-q17_genderbalance   1.091528e-12   89.777060   15
# 40          q12_diversity-q17_diversity   6.046241e-14   96.477259   15
# 41             q12_diversity-q17_equity   2.592946e-13   93.114916   15
# 42          q12_diversity-q17_inclusion   1.107490e-12   89.743248   15
# 45        q12_diversity-q03_subregional   3.943840e-02  103.557103   80
# 58                       q12_equity-q09   7.407867e-03   24.073424   10
# 59                       q12_equity-q11   1.888169e-02   21.333932   10
# 60         q12_equity-q12_genderbalance  1.661531e-111  604.111131   25
# 61             q12_equity-q12_diversity  2.964183e-119  641.159182   25
# 62             q12_equity-q12_inclusion  1.637566e-147  775.657922   25
# 63                       q12_equity-q14   1.521236e-10   97.708775   25
# 64         q12_equity-q17_genderbalance   1.971908e-08   66.359135   15
# 65             q12_equity-q17_diversity   3.443565e-11   81.676601   15
# 66                q12_equity-q17_equity   5.390766e-20  127.934666   15
# 67             q12_equity-q17_inclusion   1.408805e-13   94.525960   15
# 75                    q12_inclusion-q01   1.280153e-02   62.554046   40
# 77                    q12_inclusion-q03   2.342512e-05  142.163316   80
# 85      q12_inclusion-q12_genderbalance   1.887248e-99  546.288615   25
# 86          q12_inclusion-q12_diversity  4.416252e-108  587.709633   25
# 87             q12_inclusion-q12_equity  1.637566e-147  775.657922   25
# 88                    q12_inclusion-q14   6.152220e-12  105.940428   25
# 89      q12_inclusion-q17_genderbalance   2.218537e-09   71.702112   15
# 90          q12_inclusion-q17_diversity   3.234944e-10   76.343490   15
# 91             q12_inclusion-q17_equity   1.736099e-14   99.345133   15
# 92          q12_inclusion-q17_inclusion   1.596641e-16  110.022374   15
# 94           q12_inclusion-q03_regional   7.812392e-03   45.258757   25
# 95        q12_inclusion-q03_subregional   2.342512e-05  142.163316   80

# %%
for name, hm in heatmaps.items():
    if name in list(p005.questions):
        hm.properties(
            title=name,
            width=400,
            height=400,
        ).display()
# Out:
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
# alt.LayerChart(...)
